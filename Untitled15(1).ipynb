# %%
import requests
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
from datetime import datetime

# %%
def get_gold_price():
    url = "https://www.goldapi.io/api/XAU/USD"  # XAU = gold, USD = US Dollar

    headers = {
        "x-access-token": "goldapi-455cy19me1qlga0-io",  
        "Content-Type": "application/json"
    }

    try:
        response = requests.get(url, headers=headers)
        data = response.json()

        if response.status_code == 200:
            price = data.get("price")
            currency = data.get("currency")
            metal = data.get("metal")
            date = data.get("timestamp")

            print(f"\n🪙 Live Gold Price")
            print(f"Metal: {metal}")
            print(f"Currency: {currency}")
            print(f"Price: {price} {currency}")
            print(f"Timestamp: {date}")
        else:
            print("Failed to fetch data:", data.get("error"))
    except Exception as e:
        print("Error occurred:", e)

get_gold_price()
# Out:
# Failed to fetch data: Monthly API quota exceeded. Add billing details to upgrade to Unlimited reqs/month plan.

# %%
#pip install matplotlib requests

# %%
plt.figure(figsize=(10, 5))
plt.plot(timestamps, prices, marker='o')
plt.title('📈 Live Gold Price in USD')
plt.xlabel('Timestamp')
plt.ylabel('Price (USD)')
plt.xticks(rotation=45)
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sren Sreynich\AppData\Local\Temp\ipykernel_25936\789234477.py:8: UserWarning: Glyph 128200 (\N{CHART WITH UPWARDS TREND}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()

# %%
import warnings
def update(frame):
    price, timestamp = fetch_price()
    if price:
        prices.append(price)
        timestamps.append(datetime.now().strftime('%H:%M:%S'))
        plt.cla()
        plt.plot(timestamps, prices, marker='o')
        plt.title('Live Gold Price in USD')  # 📈 removed to fix font warning
        plt.xlabel('Time')
        plt.ylabel('Price (USD)')
        plt.xticks(rotation=45)
        plt.grid(True)
        plt.tight_layout()

fig = plt.figure()
ani = FuncAnimation(fig, update, interval=5000, cache_frame_data=False)  
plt.show()

# %%
# Plotting the histogram
plt.figure(figsize=(8, 5))
plt.hist(prices, bins=5, edgecolor='black')
plt.title('📊 Gold Price Distribution Histogram')
plt.xlabel('Price (USD)')
plt.ylabel('Frequency')
plt.tight_layout()
plt.show()
# Out:
# C:\Users\Sren Sreynich\AppData\Local\Temp\ipykernel_25936\1619940739.py:7: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
